# %% [markdown]
# # **1. 코랩의 성능**

# %% [markdown]
# ### 1-1. OS 환경

# %%
# !cat /etc/issue.net # ! = 리눅스 명령어. 현재 내 os가 어떤 걸 쓰고 있는지?
# Out:
# Ubuntu 22.04.3 LTS

# %% [markdown]
# ### 1-2. Python 버전

# %%
# !python --version # 구글 코랩에 설치돼있는 파이썬 버전
# Out:
# Python 3.10.12

# %% [markdown]
# # **2. 셀의 종류**
# * 코드: 파이썬 코드 및 리눅스 명령어를 실행할 수 있는 셀
# * 텍스트: 설명을 달거나 문구 등을 적기 위한 텍스트 전용 셀 (마크다운)

# %% [markdown]
# ### 2-1. 셀의 삽입 방법
# * 상단의 "+코드", "+텍스트" 버튼을 눌러 삽입
# * 코드셀을 위에 삽입: 컨트롤 + M A
# * 코드셀을 아레에 삽입: 컨트롤 + M B

# %% [markdown]
# ### 2-2. 셀을 변경하는 방법
# * 코드셀을 텍스트셀로 변경: 컨트롤 + M M
# * 텍스트셀을 코드셀로 변경: 컨트롤 + M Y

# %% [markdown]
# ### 2-3. 셀을 삭제하는 방법
# * 우측의 휴지통 아이콘을 클릭하여 삭제
# * 컨트롤 + M D

# %% [markdown]
# ### 2-4. 실행을 취소하는 방법
# * 컨트롤 + M Z

# %% [markdown]
# # **3. 셀의 실행**
# * 컨트롤 + 엔터: 해당 셀을 실행하고 커서는 해당 셀에 남음
# + 쉬프트 + 엔터: 해당 셀을 실행하고 다음 셀로 넘어감
# * 알트 + 엔터: 해당 셀을 실행하고 커서는 다음 셀을 삽입 후 넘어감
