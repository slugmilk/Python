# %% [markdown]
# # **1. 변수**
# 변수는 프로그래밍에서 데이터를 저장하고 관리하는 데 사용되는 중요한 개념입니다. 변수는 이름이 붙은 메모리 공간으로, 값을 저장하거나 참조할 때 사용됩니다.

# %%
name = '유민콩'
print(name) # 따옴표 사용하지 않는다
# Out:
# 유민콩

# %%
name = '김유현' # name이 가르키는 데이터의 주소가 바뀜
att = '병신'
print(name, att)
# Out:
# 김유현 병신

# %% [markdown]
# # **2. 변수의 이름 작성하는 방법**
# 파이썬의 변수는 대소문자를 구분하며, 예약어(ex: if, while, for 등)는 변수 이름으로 사용할 수 없습니다. 변수 이름은 알파벳으로 시작해야하며, 숫자나 특수문자는 척 글자로 올 수 없습니다. 변수 이름은 의미있고 알아보기 쉬운 이름으로 지정하는 것이 좋습니다.

# %%
name = '유민통' # 대소문자를 구분한다. 관례적으로 소문자를 많이 씀
Name = '정현콩'
NAME = '수현콩'

print(name)
print(Name)
print(NAME)
# Out:
# 유민통
# 정현콩
# 수현콩

# %%
name1 = '유민콩' # 1name = '유민콩' (X)
student_name = '유민콩'

# %%
이름 = '유민콩'
print(이름) # 변수명을 한글로 사용해도 되나, 운영체제가 바꾸면 깨져 코드의 재활용을 위해 변수명을 영어로 설정하는 것이 좋다.
# Out:
# 유민콩

# %% [markdown]
# # **3. 변수의 자료형**
# 파이썬은 동적 타이핑(dynamic typing)언어로, 변수의 타입을 선언할 필요 없이 값을 할당할 떄 자동으로 타입을 추론합니다. 이는 프로그래머가 변수의 타입을 직접 명시할 필요 없이 더 유연하게 코드를 작성할 수 있는 장점을 제공합니다. 그렇지만 이로 인해 잘못된 타입의 값이 변수에 할당되는 상황도 발생할 수 있습니다.

# %% [markdown]
# 1. 기본 데이터 타입: 파이썬이 제공하는 기본적인 데이터 타입입니다.
# * 정수 타입 (int): 정수 값을 나타냅니다. 예를 들어, x = 5와 같이 할당될 수 있습니다.
# * 부동소수점 타입 (float): 실수 값을 나타냅니다. 예를 들어, pi = 3.14와 같이 할당될 수 있습니다.
# * 문자열 타입 (str): 문자나 문자열을 나타냅니다. 예를 들어, name = "김사과"와 같이 할당될 수 있습니다.
# * 부울 타입 (bool): 참(True) 또는 거짓(False) 값을 나타냅니다. 예를 들어, is_love = True와 같이 할당될 수 있습니다.
#
#
#
# 2. 컬렉션 데이터 타입: 여러 개의 값을 묶어서 관리하는 데 사용되며, 더 복잡한 데이터 구조를 나타냅니다.
# * 리스트 (list): 여러 값을 순차적으로 저장하는 자료구조입니다. [1, 2, 3]와 같이 할당될 수 있습니다.
# * 튜플 (tuple): 리스트와 유사하지만 변경할 수 없는(immutable) 자료구조입니다. (1, 2, 3)와 같이 할당될 수 있습니다.
# * 딕셔너리 (dict): 키(key)와 값(value)을 쌍으로 저장하는 자료구조입니다. {"name": "김사과", "age": 20}와 같이 할당될 수 있습니다.
# * 집합 (set): 중복되지 않는 값을 저장하는 자료구조입니다. {1, 2, 3}와 같이 할당될 수 있습니다.

# %%
name = '유민콩'
print(type(name))

age = 5
print(type(age))

weight = 13.2
print(type(weight))

isLover = True
print(type(isLover))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # **4. 변수의 삭제**
# 변수를 삭제하기 위해 del문을 사용할 수 있습니다. del문은 지정된 변수를 제거하고 해당 메모리 공간을 헤제합니다. 변수가 삭제되면 해당 이름으로 변수에 더 이상 접근할 수 없습니다.

# %%
del isLover

# %%
#print(isLover)
# NameError: name 'isLover' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-6053910d0aff> in <cell line: 1>()
# ----> 1 print(isLover)
#
# NameError: name 'isLover' is not defined

# %%
name1 = '유민콩'
name2 = name1
del name1
print(name2) # name1을 지워도 '유민콩'의 주소는 이미 name2에 저장되어 name2는 정상출력된다.
# Out:
# 유민콩
