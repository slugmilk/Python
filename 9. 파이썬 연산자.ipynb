# %% [markdown]
# # **1. 산술 연산자**
# 산술 연산자는 주로 수치 데이터 유형에 대한 기본 산술 연산을 수행하기 위해 사용됩니다.
# ```
# + : 더하기
# - : 빼기
# * : 곱하기
# / : 나누기
# //: 몫 (정수 나누기)
# % : 나머지
# **: 지수 (거듭제곱)
# ```

# %%
print(10 + 8)
print(10 - 8)
print(10 * 8)
print(10 / 5)
print(10 // 8)
print(10 % 8)
print(10 ** 2)
# Out:
# 18
# 2
# 80
# 2.0
# 1
# 2
# 100

# %% [markdown]
# # **2. 비교 연산자**
# 비교 연산자는 주로 두 값을 비교하는 데 사용되며, 그 결과는 항상 불리언(True 또는 False) 값입니다.
# ```
# ==: 동등
# !=: 동등하지 않음
# < : 작다
# <=: 작거나 같다
# > : 크다
# >=: 크거나 같다
# ```

# %%
print(10 > 5)
print(10 < 5)
print(10 >= 5)
print(10 <= 5)
print(10 == 5)
print(10 != 5)
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# # **3. 할당 연산자**
# 변수에 값을 할당하는데 사용됩니다. 파이썬에서는 기본 할당 연산자 외에도 복합 할당 연산자를 제공하여 코드를 간결하게 작성할 수 있게 도와줍니다.
# ```
# = : 할당
# += : 더하기 후 할당
# -= : 빼기 후 할당
# *= : 곱하기 후 할당
# /= : 나누기 후 할당
# //=: 몫 후 할당
# %= : 나머지 후 할당
# **=: 지수 후 할당
# ```

# %%
num = 10
print(num)
num += 1
print(num)
num -= 10
print(num)
num *= 10
print(num)
num /= 10
print(num)
num %= 2
print(num)
# Out:
# 11
# 1
# 10
# 1.0
# 1.0

# %% [markdown]
# # **4. 비트 연산자**
# 비트 연산자는 정수를 이진 비트로 표현했을 때 사용하는 연산자들입니다. 각 연산자는 정수의 비트 단위로 동작합니다.
# ```
# & : 비트 단위 AND
# | : 비트 단위 OR
# ^ : 비트 단위 XOR
# ~ : 비트 단위 NOT
# << : 왼쪽 시프트
# >> : 오른쪽 시프트
# ```

# %% [markdown]
# ※ 데이터의 크기를 나타내는 용량 단위
# * Bit: 가장 기본적인 데이터 단위로, 0 또는 1의 값을 가질 수 있습니다.
# * Byte (B): 8 bits와 동일합니다.
# * Kilobyte (KB): 1 KB = 1,024 Bytes
# * Megabyte (MB): 1 MB = 1,024 KB
# * Gigabyte (GB): 1 GB = 1,024 MB
# * Terabyte (TB): 1 TB = 1,024 GB

# %%
num1 = 60 # 111100
num2 = 13 # 001101

print(num1 & num2) # 1100 -> 12
print(num1 | num2) # 111101 -> 61
print(num1 ^ num2) # 서로 다르면 1 같으면 0 -> 110001 -> 49
print(~num1) # 00111100 -> 11000011 / 맨 앞자리가 0이면 양수 1이면 음수
print(num1 << 2)  # 11110000 / 왼쪽으로 소수점 두자리
print(num1 >> num2) # 1111 / 오른쪽으로 소수점 두자리
# Out:
# 12
# 61
# 49
# -61
# 491520
# 0

# %% [markdown]
# # **5. 논리 연산자**
# 파이썬에서의 논리 연산자는 주로 불린(Boolean) 값을 조작하기 위해 사용됩니다. 그러나 파이썬의 논리 연산자는 다른 언어와는 다르게, 연산의 결과로 항상 True 또는 False만을 반환하는 것은 아닙니다. 대신 마지막으로 평가된 피연산자의 값을 반환합니다.
# ```
# and: 논리 AND
# or : 논리 OR
# not: 논리 NOT
# ```

# %%
print(True and True)
print(True and False)
print(False and False)

print(True or True)
print(True or False)
print(False or False)

print(not True)
print(not False)
# Out:
# True
# False
# False
# True
# True
# False
# False
# True

# %%
num1 = 10
num2 = 5
result1 = num1 > num2
result2 = num1 == num2 # 논리 연산자가 대입 연산자보다 운선순위가 위이기 때문에 그 뭐시기냐 괄호 필요 없음

# and: 앞의 식이 True고 뒤의 식이 True면 결과가 True인 연산
print(result1 and result2) # F
# or: 앞 뒤 식 중 적어도 하나가 True면 결과가 True
print(result1 or result2) # T
# not: 식의 값을 반대 부호로 변횐
print(not result1)
# Out:
# False
# True
# False

# %% [markdown]
# # **6. 파이썬에서 불린(Boolean)으로 평가되는 주요 값
# 1. True로 평가되는 주요 값
#
# ```
# Boolean: True
# 값이 있는 숫자: 예를 들어, -1, 1, 3.5 등 (단, 0 제외)
# 문자열과 바이트 문자열: 예를 들어, 'hello', "world", b'hello' (단, 빈 문자열 '' 및 b'' 제외)
# 모든 리스트, 튜플, 세트, 딕셔너리: 예를 들어, [1, 2], {'key': 'value'} 등 (단, 빈 컨테이너 제외)
# ```
#
# 2. False로 평가되는 주요 값
#
# ```
# Boolean: False
# 숫자: 0 (정수, 부동 소수점, 복소수 포함)
# 문자열: 빈 문자열 '' 및 빈 바이트 문자열 b''
# 리스트, 튜플, 세트: 빈 리스트 [], 빈 튜플 (), 빈 세트 set()
# 딕셔너리: 빈 딕셔너리 {}
# None: 파이썬의 None 객체도 False로 평가됩니다.
# ```

# %%
print(False and 10) # and는 앞을 먼저 봤을 때 앞의 값이 False면 무조건 앞의 값을 반환한다. 뒤의 값을 보나마나 False니까.
print(True and 10) # 앞의 값이 True면 뒤의 값을 확인해 뒤의 값이 True면 뒤의 값을 반환.
print(0 and True) # 0은 False로 판단되므로 뒤로 가지 않고 에잇 시부렁 0 반환
print(1 and 10) # 1과 10 모두 True이므로 뒤의 값인 10이 반환
# Out:
# False
# 10
# 0
# 10
# True

# %%
print(True or 10) # 앞에만 True여도 True니까 걍 True 번환
print(10 or True) # 10이 True니까 10
print(False or 3) # 앞이 False니까 뒤의 값 반환
print('Hello' or 3)
print(0 or '') # 빈 문자열 반환
print(0 or 'Hello')
# Out:
# True
# 10
# 3
# Hello
#
# Hello

# %%
print(not True) # false
print(not 0) # true
print(not 'hello') # false
# Out:
# False
# True
# False
